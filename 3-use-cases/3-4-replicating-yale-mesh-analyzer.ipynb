# %% [markdown]
# # 3.4 Replicating Yale MeSH Analyzer
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hscells/apis-for-evidence-identification/blob/main/3-use-cases/3-4-replicating-yale-mesh-analyzer.ipynb)
#
# In this notebook we will replicate the [Yale MeSH Analyzer](https://mesh.med.yale.edu/). This is a tool that allows users to input a series of PMIDs and it will return a list of MeSH terms that are associated with those studies.  We will see how we can use the APIs we have discussed to completely replicate this tool. We'll continue to use the running example of data from "[Blue-Light Therapy for Acne Vulgaris: A Systematic Review and Meta-Analysis](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6846280/)"

# %%
# !pip install requests pandas -q
import requests
import pandas as pd
from collections import Counter

# %% [markdown]
# We will keep using the same set of seed studies we've been using in the last few notebooks.

# %%
seed_studies = ["27575854", "25594129", "20098847", "22091799", "23278295", "24313686", "29152718", "10809858",
                "18664153", "15379878"]

# %% [markdown]
# First, we need to get the MeSH terms associated with each study. For a deeper explaination of the next cell, take a look at [Section 3.2](https://github.com/hscells/apis-for-evidence-identification/blob/main/3-use-cases/3-2-searching-clinicaltrials-gov.ipynb).

# %%
response = requests.get(  # GET request
    url="https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi",  # URL of the API
    params={  # Parameters of the request
        "db": "pubmed",
        "id": ",".join(seed_studies),  # We can get multiple PMIDs at once
        "rettype": "medline",
        "retmode": "text"
    }
).text

pubmed_studies = []  # This will contain all the studies once processed
sections = response.split("\n\n")  # Thankfully, the responses can be split easily on two empty lines

for section in sections:  # Now, we process each section.
    # The next few lines of code convert the lines into a JSON format
    data_dict = {}
    last_key = None
    for line in section.splitlines():
        if line.strip() == "":
            continue
        if line[4] == "-":
            line = line.split("-")
            last_key = line[0].strip()
            if last_key in data_dict:
                if not isinstance(data_dict[last_key], list):
                    data_dict[last_key] = [data_dict[last_key]]
                data_dict[last_key].append(line[1].strip())
            else:
                data_dict[last_key] = line[1].strip()
        else:
            data_dict[last_key] += line.strip() + " "

    pubmed_studies.append(data_dict)
len(seed_studies), len(pubmed_studies)
# Out:
# (10, 10)

# %% [markdown]
# The cell above should have returned the same number of studies as we have seed studies. Now we can take a look at the MeSH terms associated with each study. First, let's look at all the data we extracted.

# %%
df_studies = pd.DataFrame(pubmed_studies)
df_studies
# Out:
#        PMID  OWN     STAT      DCOM        LR            IS   VI  IP  \
# 0  27575854  NLM  MEDLINE  20170626  20220408  [1365, 0011]   55  12
# 1  25594129  NLM  MEDLINE  20160512  20161125  [1476, 1476]   17   4
# 2  20098847  NLM  MEDLINE  20100603  20191120  [1806, 0365]   84   5
# 3  22091799  NLM  MEDLINE  20120308  20111118  [1476, 1476]   13   6
# 4  23278295  NLM  MEDLINE  20131113  20221207  [1365, 0007]  168   5
# 5  24313686  NLM  MEDLINE  20150522  20140916  [1600, 0905]   30   5
# 6  29152718  NLM  MEDLINE  20180807  20180807  [1365, 0011]   57   1
# 7  10809858  NLM  MEDLINE  20000629  20220316  [0007, 0007]  142   5
# 8  18664153  NLM  MEDLINE  20080926  20220311  [1545, 1545]    7   7
# 9  15379878  NLM  MEDLINE  20050201  20220317  [0905, 0905]   20   5
#
#          DP                                                 TI  ...  \
# 0  2016 Dec  A multicenter, randomized, splitsafety of chro...  ...
# 1      2015  A randomized controlled study for the treatmen...  ...
# 2  2009 Sep  [A prospective, randomized, open and comparati...  ...
# 3  2011 Dec                          Clinical efficacy of home  ...
# 4  2013 May  The clinical and histological effect of homeph...  ...
# 5  2014 Oct  Randomized trial of three phototherapy methods...  ...
# 6  2018 Jan  An extension of a multicenter, randomized, spl...  ...
# 7  2000 May  Phototherapy with blue (415 nm) and red (660 n...  ...
# 8  2008 Jul    Phototherapy in the treatment of acne vulgaris.  ...
# 9  2004 Oct  Blue light phototherapy in the treatment of acne.  ...
#
#                EDAT              MHDA              CRDT  \
# 0  2016/11/05 06:00  2017/06/27 06:00  2016/08/31 06:00
# 1  2015/01/17 06:00  2016/05/14 06:00  2015/01/17 06:00
# 2  2010/01/26 06:00  2010/06/04 06:00  2010/01/26 06:00
# 3  2011/11/19 06:00  2012/03/09 06:00  2011/11/19 06:00
# 4  2013/01/03 06:00  2013/11/14 06:00  2013/01/03 06:00
# 5  2013/12/10 06:00  2015/05/23 06:00  2013/12/10 06:00
# 6  2017/11/21 06:00  2018/08/08 06:00  2017/11/21 06:00
# 7  2000/05/16 09:00  2000/07/06 11:00  2000/05/16 09:00
# 8  2008/07/31 09:00  2008/09/27 09:00  2008/07/31 09:00
# 9  2004/09/24 05:00  2005/02/03 09:00  2004/09/24 05:00
#
#                                                 PHST  \
# 0  [2015/12/06 00:00 [received], 2016/02/28 00:00...
# 1  [2015/01/17 06:00 [entrez], 2015/01/17 06:00 [...
# 2  [2008/05/20 00:00 [received], 2009/07/31 00:00...
# 3  [2011/11/19 06:00 [entrez], 2011/11/19 06:00 [...
# 4  [2013/01/03 06:00 [entrez], 2013/01/03 06:00 [...
# 5  [2013/12/03 00:00 [accepted], 2013/12/10 06:00...
# 6  [2016/12/21 00:00 [received], 2017/08/17 00:00...
# 7  [2000/05/16 09:00 [pubmed], 2000/07/06 11:00 [...
# 8  [2008/07/31 09:00 [pubmed], 2008/09/27 09:00 [...
# 9  [2004/09/24 05:00 [pubmed], 2005/02/03 09:00 [...
#
#                                    AID       PST  \
# 0              10.1111/ijd.13349 [doi]  ppublish
# 1  10.3109/14764172.2015.1007064 [doi]  ppublish
# 2               [S0365, 10.1590/s0365]  ppublish
# 3   10.3109/14764172.2011.630081 [doi]  ppublish
# 4              10.1111/bjd.12186 [doi]  ppublish
# 5             10.1111/phpp.12098 [doi]  ppublish
# 6              10.1111/ijd.13814 [doi]  ppublish
# 7      [bjd3481 [pii], 10.1046/j.1365]  ppublish
# 8                                  NaN  ppublish
# 9       [PPP109 [pii], 10.1111/j.1600]  ppublish
#
#                                                   SO     OTO  \
# 0           Int J Dermatol. 2016 Dec;55(12):132130.      NaN
# 1   J Cosmet Laser Ther. 2015;17(4):1702015 Feb 20.   NOTNLM
# 2                         An Bras Dermatol. 2009 Sep     NaN
# 3            J Cosmet Laser Ther. 2011 Dec;13(6):308     NaN
# 4                Br J Dermatol. 2013 May;168(5):1088     NaN
# 5  Photodermatol Photoimmunol Photomed. 2014 Oct;...  NOTNLM
# 6                  Int J Dermatol. 2018 Jan;57(1):94     NaN
# 7                 Br J Dermatol. 2000 May;142(5):973     NaN
# 8                J Drugs Dermatol. 2008 Jul;7(7):627     NaN
# 9  Photodermatol Photoimmunol Photomed. 2004 Oct;...     NaN
#
#                                                   OT  \
# 0                                                NaN
# 1  [LED, RCT, acne vulgaris, light, photorejuvena...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  [acne vulgaris, intense pulsed light, light, p...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                                   TT
# 0                                                NaN
# 1                                                NaN
# 2  Estudo clinico, prospectivo, aberto, randomiza...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
# [10 rows x 38 columns]

# %% [markdown]
# We can filter the columns of this table down to just the PMID, Title, and MeSH terms.

# %%
df_studies[["PMID", "TI", "MH"]]
# Out:
#        PMID                                                 TI  \
# 0  27575854  A multicenter, randomized, splitsafety of chro...
# 1  25594129  A randomized controlled study for the treatmen...
# 2  20098847  [A prospective, randomized, open and comparati...
# 3  22091799                          Clinical efficacy of home
# 4  23278295  The clinical and histological effect of homeph...
# 5  24313686  Randomized trial of three phototherapy methods...
# 6  29152718  An extension of a multicenter, randomized, spl...
# 7  10809858  Phototherapy with blue (415 nm) and red (660 n...
# 8  18664153    Phototherapy in the treatment of acne vulgaris.
# 9  15379878  Blue light phototherapy in the treatment of acne.
#
#                                                   MH
# 0  [Acne Vulgaris/complications/*therapy, Adolesc...
# 1  [Acne Vulgaris/*therapy, Adolescent, Adult, Co...
# 2  [Acne Vulgaris/*therapy, Administration, Topic...
# 3  [Acne Vulgaris/pathology/*therapy, Adult, Face...
# 4  [Acne Vulgaris/pathology/*therapy, Asian Peopl...
# 5  [Acne Vulgaris/*therapy, Adolescent, Adult, Fe...
# 6  [Acne Vulgaris/*therapy, Adolescent, Adult, Co...
# 7  [Acne Vulgaris/*therapy, Adolescent, Adult, Be...
# 8  [Acne Vulgaris/drug therapy/*therapy, Adult, F...
# 9  [Acne Vulgaris/classification/pathology/*thera...

# %% [markdown]
# This isn't particularly useful, since all the MeSH terms are in a single string. We need to instead invert this list so that each MeSH term corresponds to a study. That's exactly what the next cell does.

# %%
mesh_index = {}
for study in pubmed_studies:
    for term in study["MH"]:
        if term not in mesh_index:
            mesh_index[term] = [0] * len(pubmed_studies)
        if term in study["MH"]:
            mesh_index[term][pubmed_studies.index(study)] = 1
mesh_index["Adult"]
# Out:
# [1, 1, 0, 1, 0, 1, 1, 1, 1, 1]

# %% [markdown]
# Now, we've got this data in a format that tells us which studies the MeSH term appears in. If it's a 1, then the MeSH term appears in the study. If it's a 0, then it doesn't. We can now convert this into a table for easier viewing.

# %%
pd.DataFrame(mesh_index).T.rename(columns={i: seed_studies[i] for i in range(len(seed_studies))}).sort_index()
# Out:
#                                                     27575854  25594129  \
# *Phototherapy                                              0         0
# *Phototherapy/instrumentation                              0         0
# Acne Vulgaris/*therapy                                     0         1
# Acne Vulgaris/classification/pathology/*therapy            0         0
# Acne Vulgaris/complications/*therapy                       1         0
# Acne Vulgaris/drug therapy/*therapy                        0         0
# Acne Vulgaris/pathology/*therapy                           0         0
# Administration, Topical                                    0         0
# Adolescent                                                 1         1
# Adult                                                      1         1
# Asian People                                               0         0
# Benzoyl Peroxide/*administration & dosage/adver...         0         0
# Benzoyl Peroxide/adverse effects/therapeutic use           0         0
# Cicatrix, Hypertrophic/pathology                           0         0
# Cicatrix/classification/pathology                          0         0
# Color                                                      0         0
# Combined Modality Therapy                                  0         1
# Cosmetic Techniques                                        0         1
# Dermatologic Agents/*administration & dosage/ad...         0         0
# Dermatologic Agents/adverse effects/therapeutic...         0         0
# Double                                                     0         1
# Face                                                       0         0
# Facial Dermatoses/*therapy                                 0         0
# Facial Dermatoses/classification/pathology/therapy         0         0
# Female                                                     1         1
# Fluorescence                                               0         0
# Follow                                                     0         0
# Gels                                                       1         0
# Glycolates/therapeutic use                                 0         1
# Hair Follicle/metabolism                                   0         0
# Humans                                                     1         1
# Keratolytic Agents/administration & dosage/*the...         0         1
# Lactic Acid/therapeutic use                                0         1
# Laser Therapy/adverse effects/*methods                     0         0
# Male                                                       1         1
# Middle Aged                                                0         1
# Pain/etiology                                              1         0
# Patient Compliance                                         0         0
# Photochemotherapy/adverse effects/methods                  0         0
# Phototherapy/*adverse effects/*methods                     1         0
# Phototherapy/*instrumentation                              0         1
# Phototherapy/*methods                                      0         0
# Phototherapy/adverse effects/*methods                      0         0
# Porphyrins/analysis                                        0         0
# Prospective Studies                                        1         0
# Quality of Life                                            1         0
# Republic of Korea                                          0         0
# Salicylic Acid/therapeutic use                             0         1
# Sebaceous Glands/metabolism                                0         0
# Self Administration                                        0         0
# Severity of Illness Index                                  1         1
# Single                                                     0         0
# Skin/pathology                                             0         0
# Treatment Outcome                                          0         0
# Young Adult                                                1         1
#
#                                                     20098847  22091799  \
# *Phototherapy                                              1         0
# *Phototherapy/instrumentation                              0         1
# Acne Vulgaris/*therapy                                     1         0
# Acne Vulgaris/classification/pathology/*therapy            0         0
# Acne Vulgaris/complications/*therapy                       0         0
# Acne Vulgaris/drug therapy/*therapy                        0         0
# Acne Vulgaris/pathology/*therapy                           0         1
# Administration, Topical                                    1         0
# Adolescent                                                 1         0
# Adult                                                      0         1
# Asian People                                               0         0
# Benzoyl Peroxide/*administration & dosage/adver...         1         0
# Benzoyl Peroxide/adverse effects/therapeutic use           0         0
# Cicatrix, Hypertrophic/pathology                           0         0
# Cicatrix/classification/pathology                          0         0
# Color                                                      0         0
# Combined Modality Therapy                                  0         0
# Cosmetic Techniques                                        0         0
# Dermatologic Agents/*administration & dosage/ad...         1         0
# Dermatologic Agents/adverse effects/therapeutic...         0         0
# Double                                                     0         0
# Face                                                       0         1
# Facial Dermatoses/*therapy                                 0         0
# Facial Dermatoses/classification/pathology/therapy         0         0
# Female                                                     1         1
# Fluorescence                                               0         0
# Follow                                                     0         0
# Gels                                                       0         0
# Glycolates/therapeutic use                                 0         0
# Hair Follicle/metabolism                                   0         0
# Humans                                                     1         1
# Keratolytic Agents/administration & dosage/*the...         0         0
# Lactic Acid/therapeutic use                                0         0
# Laser Therapy/adverse effects/*methods                     0         0
# Male                                                       1         1
# Middle Aged                                                0         0
# Pain/etiology                                              0         0
# Patient Compliance                                         0         0
# Photochemotherapy/adverse effects/methods                  0         0
# Phototherapy/*adverse effects/*methods                     0         0
# Phototherapy/*instrumentation                              0         0
# Phototherapy/*methods                                      0         0
# Phototherapy/adverse effects/*methods                      0         0
# Porphyrins/analysis                                        0         0
# Prospective Studies                                        1         1
# Quality of Life                                            0         0
# Republic of Korea                                          0         0
# Salicylic Acid/therapeutic use                             0         0
# Sebaceous Glands/metabolism                                0         0
# Self Administration                                        0         1
# Severity of Illness Index                                  1         1
# Single                                                     0         0
# Skin/pathology                                             0         0
# Treatment Outcome                                          0         0
# Young Adult                                                0         0
#
#                                                     23278295  24313686  \
# *Phototherapy                                              0         0
# *Phototherapy/instrumentation                              0         0
# Acne Vulgaris/*therapy                                     0         1
# Acne Vulgaris/classification/pathology/*therapy            0         0
# Acne Vulgaris/complications/*therapy                       0         0
# Acne Vulgaris/drug therapy/*therapy                        0         0
# Acne Vulgaris/pathology/*therapy                           1         0
# Administration, Topical                                    0         0
# Adolescent                                                 0         1
# Adult                                                      0         1
# Asian People                                               1         0
# Benzoyl Peroxide/*administration & dosage/adver...         0         0
# Benzoyl Peroxide/adverse effects/therapeutic use           0         0
# Cicatrix, Hypertrophic/pathology                           0         0
# Cicatrix/classification/pathology                          0         0
# Color                                                      0         0
# Combined Modality Therapy                                  0         0
# Cosmetic Techniques                                        0         0
# Dermatologic Agents/*administration & dosage/ad...         0         0
# Dermatologic Agents/adverse effects/therapeutic...         0         0
# Double                                                     1         0
# Face                                                       0         0
# Facial Dermatoses/*therapy                                 0         0
# Facial Dermatoses/classification/pathology/therapy         0         0
# Female                                                     1         1
# Fluorescence                                               0         0
# Follow                                                     0         0
# Gels                                                       0         0
# Glycolates/therapeutic use                                 0         0
# Hair Follicle/metabolism                                   0         0
# Humans                                                     1         1
# Keratolytic Agents/administration & dosage/*the...         0         0
# Lactic Acid/therapeutic use                                0         0
# Laser Therapy/adverse effects/*methods                     0         0
# Male                                                       1         1
# Middle Aged                                                0         0
# Pain/etiology                                              0         0
# Patient Compliance                                         0         0
# Photochemotherapy/adverse effects/methods                  0         0
# Phototherapy/*adverse effects/*methods                     0         0
# Phototherapy/*instrumentation                              0         0
# Phototherapy/*methods                                      0         1
# Phototherapy/adverse effects/*methods                      1         0
# Porphyrins/analysis                                        0         0
# Prospective Studies                                        0         0
# Quality of Life                                            0         0
# Republic of Korea                                          1         0
# Salicylic Acid/therapeutic use                             0         0
# Sebaceous Glands/metabolism                                1         0
# Self Administration                                        0         0
# Severity of Illness Index                                  1         0
# Single                                                     0         0
# Skin/pathology                                             0         0
# Treatment Outcome                                          1         0
# Young Adult                                                0         1
#
#                                                     29152718  10809858  \
# *Phototherapy                                              0         0
# *Phototherapy/instrumentation                              0         0
# Acne Vulgaris/*therapy                                     1         1
# Acne Vulgaris/classification/pathology/*therapy            0         0
# Acne Vulgaris/complications/*therapy                       0         0
# Acne Vulgaris/drug therapy/*therapy                        0         0
# Acne Vulgaris/pathology/*therapy                           0         0
# Administration, Topical                                    0         0
# Adolescent                                                 1         1
# Adult                                                      1         1
# Asian People                                               0         0
# Benzoyl Peroxide/*administration & dosage/adver...         0         0
# Benzoyl Peroxide/adverse effects/therapeutic use           0         1
# Cicatrix, Hypertrophic/pathology                           0         0
# Cicatrix/classification/pathology                          0         0
# Color                                                      1         0
# Combined Modality Therapy                                  0         0
# Cosmetic Techniques                                        0         0
# Dermatologic Agents/*administration & dosage/ad...         0         0
# Dermatologic Agents/adverse effects/therapeutic...         0         1
# Double                                                     0         0
# Face                                                       0         0
# Facial Dermatoses/*therapy                                 1         0
# Facial Dermatoses/classification/pathology/therapy         0         0
# Female                                                     1         1
# Fluorescence                                               0         0
# Follow                                                     0         0
# Gels                                                       1         0
# Glycolates/therapeutic use                                 0         0
# Hair Follicle/metabolism                                   0         0
# Humans                                                     1         1
# Keratolytic Agents/administration & dosage/*the...         0         0
# Lactic Acid/therapeutic use                                0         0
# Laser Therapy/adverse effects/*methods                     0         0
# Male                                                       1         1
# Middle Aged                                                0         1
# Pain/etiology                                              0         0
# Patient Compliance                                         1         0
# Photochemotherapy/adverse effects/methods                  0         0
# Phototherapy/*adverse effects/*methods                     0         0
# Phototherapy/*instrumentation                              0         0
# Phototherapy/*methods                                      0         0
# Phototherapy/adverse effects/*methods                      1         1
# Porphyrins/analysis                                        0         0
# Prospective Studies                                        0         0
# Quality of Life                                            0         0
# Republic of Korea                                          0         0
# Salicylic Acid/therapeutic use                             0         0
# Sebaceous Glands/metabolism                                0         0
# Self Administration                                        0         0
# Severity of Illness Index                                  1         0
# Single                                                     0         1
# Skin/pathology                                             0         0
# Treatment Outcome                                          1         1
# Young Adult                                                1         0
#
#                                                     18664153  15379878
# *Phototherapy                                              0         0
# *Phototherapy/instrumentation                              0         0
# Acne Vulgaris/*therapy                                     0         0
# Acne Vulgaris/classification/pathology/*therapy            0         1
# Acne Vulgaris/complications/*therapy                       0         0
# Acne Vulgaris/drug therapy/*therapy                        1         0
# Acne Vulgaris/pathology/*therapy                           0         0
# Administration, Topical                                    0         0
# Adolescent                                                 0         1
# Adult                                                      1         1
# Asian People                                               0         0
# Benzoyl Peroxide/*administration & dosage/adver...         0         0
# Benzoyl Peroxide/adverse effects/therapeutic use           0         0
# Cicatrix, Hypertrophic/pathology                           0         1
# Cicatrix/classification/pathology                          0         1
# Color                                                      0         0
# Combined Modality Therapy                                  0         0
# Cosmetic Techniques                                        0         0
# Dermatologic Agents/*administration & dosage/ad...         0         0
# Dermatologic Agents/adverse effects/therapeutic...         0         0
# Double                                                     0         0
# Face                                                       0         0
# Facial Dermatoses/*therapy                                 0         0
# Facial Dermatoses/classification/pathology/therapy         0         1
# Female                                                     1         1
# Fluorescence                                               0         1
# Follow                                                     0         1
# Gels                                                       0         0
# Glycolates/therapeutic use                                 0         0
# Hair Follicle/metabolism                                   0         1
# Humans                                                     1         1
# Keratolytic Agents/administration & dosage/*the...         0         0
# Lactic Acid/therapeutic use                                0         0
# Laser Therapy/adverse effects/*methods                     1         0
# Male                                                       1         1
# Middle Aged                                                0         0
# Pain/etiology                                              0         0
# Patient Compliance                                         0         0
# Photochemotherapy/adverse effects/methods                  1         0
# Phototherapy/*adverse effects/*methods                     0         0
# Phototherapy/*instrumentation                              0         0
# Phototherapy/*methods                                      0         1
# Phototherapy/adverse effects/*methods                      1         0
# Porphyrins/analysis                                        0         1
# Prospective Studies                                        0         0
# Quality of Life                                            0         0
# Republic of Korea                                          0         0
# Salicylic Acid/therapeutic use                             0         0
# Sebaceous Glands/metabolism                                0         0
# Self Administration                                        0         0
# Severity of Illness Index                                  0         0
# Single                                                     0         0
# Skin/pathology                                             0         1
# Treatment Outcome                                          1         1
# Young Adult                                                0         0

# %% [markdown]
# We can now even go one step further and use this data to count the number of times each MeSH term appears in the studies. We just need to count the number of 1s in each column.

# %%
mesh_count = Counter()
for term, vec in mesh_index.items():
    mesh_count[term] = sum(vec)
pd.DataFrame(mesh_count.most_common(), columns=["MeSH Term", "Count"])
# Out:
#                                             MeSH Term  Count
# 0                                              Female     10
# 1                                              Humans     10
# 2                                                Male     10
# 3                                               Adult      8
# 4                                          Adolescent      7
# 5                           Severity of Illness Index      6
# 6                              Acne Vulgaris/*therapy      5
# 7                                   Treatment Outcome      5
# 8                                         Young Adult      4
# 9               Phototherapy/adverse effects/*methods      4
# 10                                Prospective Studies      3
# 11                                               Gels      2
# 12                                             Double      2
# 13                                        Middle Aged      2
# 14                   Acne Vulgaris/pathology/*therapy      2
# 15                              Phototherapy/*methods      2
# 16               Acne Vulgaris/complications/*therapy      1
# 17                                      Pain/etiology      1
# 18             Phototherapy/*adverse effects/*methods      1
# 19                                    Quality of Life      1
# 20                          Combined Modality Therapy      1
# 21                                Cosmetic Techniques      1
# 22                         Glycolates/therapeutic use      1
# 23  Keratolytic Agents/administration & dosage/*th...      1
# 24                        Lactic Acid/therapeutic use      1
# 25                      Phototherapy/*instrumentation      1
# 26                     Salicylic Acid/therapeutic use      1
# 27                            Administration, Topical      1
# 28  Benzoyl Peroxide/*administration & dosage/adve...      1
# 29  Dermatologic Agents/*administration & dosage/a...      1
# 30                                      *Phototherapy      1
# 31                                               Face      1
# 32                      *Phototherapy/instrumentation      1
# 33                                Self Administration      1
# 34                                       Asian People      1
# 35                                  Republic of Korea      1
# 36                        Sebaceous Glands/metabolism      1
# 37                                              Color      1
# 38                         Facial Dermatoses/*therapy      1
# 39                                 Patient Compliance      1
# 40   Benzoyl Peroxide/adverse effects/therapeutic use      1
# 41  Dermatologic Agents/adverse effects/therapeuti...      1
# 42                                             Single      1
# 43                Acne Vulgaris/drug therapy/*therapy      1
# 44             Laser Therapy/adverse effects/*methods      1
# 45          Photochemotherapy/adverse effects/methods      1
# 46    Acne Vulgaris/classification/pathology/*therapy      1
# 47                  Cicatrix/classification/pathology      1
# 48                   Cicatrix, Hypertrophic/pathology      1
# 49  Facial Dermatoses/classification/pathology/the...      1
# 50                                       Fluorescence      1
# 51                                             Follow      1
# 52                           Hair Follicle/metabolism      1
# 53                                Porphyrins/analysis      1
# 54                                     Skin/pathology      1

# %% [markdown]
# As before, we can save this data to a CSV file for further analysis.

# %%
pd.DataFrame(mesh_count.most_common(), columns=["MeSH Term", "Count"]).to_csv("mesh_terms.csv", index=False)
# This should save a file called mesh_terms.csv in the current directory

# %% [markdown]
# ## Summary
#
# In this notebook, we have replicated the Yale MeSH Analyzer. We have taken a list of PMIDs and extracted the MeSH terms associated with each study. We then inverted this data to show which MeSH terms appear in which studies. Finally, we counted the number of times each MeSH term appeared in the studies. The results of this notebook can be used to quickly identify the most common MeSH terms associated with a set of studies, for use in search strategy development.
#
# If you found any mistakes or have any feedback about any of the chapters, please reach out, or open an issue on the [GitHub repository](https://github.com/hscells/apis-for-evidence-identification). Thank you for reading!
#
# ---
# [top](https://github.com/hscells/apis-for-evidence-identification#table-of-contents)<br/>
# [previous: Frequency Analysis](https://github.com/hscells/apis-for-evidence-identification/blob/main/3-use-cases/3-3-frequency-analysis.ipynb)<br/>
